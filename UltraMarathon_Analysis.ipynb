# %%
#import Libraries
# Source of Dataset : https://www.kaggle.com/datasets/aiaiaidavid/the-big-dataset-of-ultra-marathon-running/data

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_21140\2350612576.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")

# %%
#see the data that's been imported

# %%
df
# Out:
#          Year of event Event dates                                Event name  \
# 0                 2018  06.01.2018                       Selva Costera (CHI)
# 1                 2018  06.01.2018                       Selva Costera (CHI)
# 2                 2018  06.01.2018                       Selva Costera (CHI)
# 3                 2018  06.01.2018                       Selva Costera (CHI)
# 4                 2018  06.01.2018                       Selva Costera (CHI)
# ...                ...         ...                                       ...
# 7461190           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461191           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461192           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461193           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461194           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
#
# ...

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
#clean up data

# %%
#Only want USA Races, 50k or 50Mi ,2020

# %%
#step 1 :Show 50k or 50Mi
#50km
#50mi

# %%
df[df['Event distance/length']=='50mi']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
#  Combine 50km/50mi with isin

# %%
df[df['Event distance/length'].isin(['50km','50mi'])]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event']==2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
df[df['Athlete country']=='USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# 60                2018  06.01.2018
# 61                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 60       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 61       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event']==2020) &(df['Athlete country']=='USA')]
# Out:
#          Year of event     Event dates  \
# 2538588           2020  07.-09.02.2020
# 2538628           2020  07.-09.02.2020
# 2538860           2020      07.02.2020
# 2538883           2020      07.02.2020
# 2539317           2020      02.02.2020
# ...                ...             ...
# 2760957           2020      03.10.2020
# 2760958           2020      03.10.2020
# 2760959           2020      03.10.2020
# 2760960           2020      03.10.2020
# 2760961           2020      03.10.2020
#
#                                            Event name Event distance/length  \
# 2538588       Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538628       Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538860      Dead Sea Marathon Ein Bokek - 50km (ISR)                  50km
# 2538883      Dead Sea Marathon Ein Bokek - 50km (ISR)                  50km
# 2539317                  Gumi Dorissa Trail Run (KOR)                  50km
# ...

# %%
df2 = df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event']==2020) &(df['Athlete country']=='USA')]

# %%
df2
# Out:
#          Year of event     Event dates  \
# 2538588           2020  07.-09.02.2020
# 2538628           2020  07.-09.02.2020
# 2538860           2020      07.02.2020
# 2538883           2020      07.02.2020
# 2539317           2020      02.02.2020
# ...                ...             ...
# 2760957           2020      03.10.2020
# 2760958           2020      03.10.2020
# 2760959           2020      03.10.2020
# 2760960           2020      03.10.2020
# 2760961           2020      03.10.2020
#
#                                            Event name Event distance/length  \
# 2538588       Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538628       Taipei 48hr Ultra Marathon - 50km (TPE)                  50km
# 2538860      Dead Sea Marathon Ein Bokek - 50km (ISR)                  50km
# 2538883      Dead Sea Marathon Ein Bokek - 50km (ISR)                  50km
# 2539317                  Gumi Dorissa Trail Run (KOR)                  50km
# ...

# %%
df2.shape
# Out:
# (26326, 13)

# %%
#remove USA From Event Name

# %%
df2['Event name'] = df2['Event name'].str.split('(').str.get(0)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_15664\3473829760.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Event name'] = df2['Event name'].str.split('(').str.get(0)

# %%
df2.head(20)
# Out:
#          Year of event     Event dates  \
# 2538588           2020  07.-09.02.2020
# 2538628           2020  07.-09.02.2020
# 2538860           2020      07.02.2020
# 2538883           2020      07.02.2020
# 2539317           2020      02.02.2020
# 2539318           2020      02.02.2020
# 2539945           2020      02.02.2020
# 2539946           2020      02.02.2020
# 2539947           2020      02.02.2020
# 2539948           2020      02.02.2020
# 2539949           2020      02.02.2020
# 2539950           2020      02.02.2020
# 2539951           2020      02.02.2020
# 2539952           2020      02.02.2020
# 2539953           2020      02.02.2020
# 2539954           2020      02.02.2020
# 2539955           2020      02.02.2020
# 2539956           2020      02.02.2020
# 2539957           2020      02.02.2020
# 2539958           2020      02.02.2020
#
#                                        Event name Event distance/length  \
# ...

# %%
df['Event dates'] = df['Event dates'].str.replace(".-09",'')
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_15664\1563372882.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Event dates'] = df['Event dates'].str.replace(".-09",'')

# %%
df
# Out:
#          Year of event Event dates                                Event name  \
# 0                 2018  06.01.2018                       Selva Costera (CHI)
# 1                 2018  06.01.2018                       Selva Costera (CHI)
# 2                 2018  06.01.2018                       Selva Costera (CHI)
# 3                 2018  06.01.2018                       Selva Costera (CHI)
# 4                 2018  06.01.2018                       Selva Costera (CHI)
# ...                ...         ...                                       ...
# 7461190           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461191           1995  00.00.1995                 La SainteLyon 65 km (FRA)
# 7461192           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461193           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
# 7461194           1995  00.00.1995  Szombathely 24 hours running Race  (HUN)
#
# ...

# %%
df2['Event dates'] = df2['Event dates'].str.replace(".-09",'')
df2
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_15664\3551700146.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2['Event dates'] = df2['Event dates'].str.replace(".-09",'')
# C:\Users\admin\AppData\Local\Temp\ipykernel_15664\3551700146.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Event dates'] = df2['Event dates'].str.replace(".-09",'')
#          Year of event Event dates                               Event name  \
# 2538588           2020  07.02.2020       Taipei 48hr Ultra Marathon - 50mi
# 2538628           2020  07.02.2020       Taipei 48hr Ultra Marathon - 50km
# 2538860           2020  07.02.2020      Dead Sea Marathon Ein Bokek - 50km
# ...

# %%
df2['Athelete_Age'] = 2020 - df2['Athlete year of birth']
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_15664\3590142716.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athelete_Age'] = 2020 - df2['Athlete year of birth']

# %%
df2
# Out:
#          Year of event Event dates                               Event name  \
# 2538588           2020  07.02.2020       Taipei 48hr Ultra Marathon - 50mi
# 2538628           2020  07.02.2020       Taipei 48hr Ultra Marathon - 50km
# 2538860           2020  07.02.2020      Dead Sea Marathon Ein Bokek - 50km
# 2538883           2020  07.02.2020      Dead Sea Marathon Ein Bokek - 50km
# 2539317           2020  02.02.2020                  Gumi Dorissa Trail Run
# ...                ...         ...                                      ...
# 2760957           2020  03.10.2020  Yankee Springs Fall Trail Run Festival
# 2760958           2020  03.10.2020  Yankee Springs Fall Trail Run Festival
# 2760959           2020  03.10.2020  Yankee Springs Fall Trail Run Festival
# 2760960           2020  03.10.2020  Yankee Springs Fall Trail Run Festival
# 2760961           2020  03.10.2020  Yankee Springs Fall Trail Run Festival
#
# ...

# %%
#removing h from Athlete performance

# %%
df2['Athlete performance'] = df2['Athlete performance'].str.replace("h",'')
df2
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_15664\1406362728.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance'] = df2['Athlete performance'].str.replace("h",'')
#          Year of event Event dates                               Event name  \
# 2538588           2020  07.02.2020       Taipei 48hr Ultra Marathon - 50mi
# 2538628           2020  07.02.2020       Taipei 48hr Ultra Marathon - 50km
# 2538860           2020  07.02.2020      Dead Sea Marathon Ein Bokek - 50km
# 2538883           2020  07.02.2020      Dead Sea Marathon Ein Bokek - 50km
# 2539317           2020  02.02.2020                  Gumi Dorissa Trail Run
# ...                ...         ...                                      ...
# ...

# %%
#drop columns : Athelete club,Athelete country,Athelete Year of birth,Athelete Age category

# %%
df2 = df2.drop(columns=['Athlete year of birth','Athlete country','Athlete club','Athlete age category'])

# %%
df2
# Out:
#          Year of event Event dates                               Event name  \
# 2538588           2020  07.02.2020       Taipei 48hr Ultra Marathon - 50mi
# 2538628           2020  07.02.2020       Taipei 48hr Ultra Marathon - 50km
# 2538860           2020  07.02.2020      Dead Sea Marathon Ein Bokek - 50km
# 2538883           2020  07.02.2020      Dead Sea Marathon Ein Bokek - 50km
# 2539317           2020  02.02.2020                  Gumi Dorissa Trail Run
# ...                ...         ...                                      ...
# 2760957           2020  03.10.2020  Yankee Springs Fall Trail Run Festival
# 2760958           2020  03.10.2020  Yankee Springs Fall Trail Run Festival
# 2760959           2020  03.10.2020  Yankee Springs Fall Trail Run Festival
# 2760960           2020  03.10.2020  Yankee Springs Fall Trail Run Festival
# 2760961           2020  03.10.2020  Yankee Springs Fall Trail Run Festival
#
# ...

# %%
#clean up null values

# %%
df2.isna().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# Athelete_Age                 223
# dtype: int64

# %%
df2[df2['Athelete_Age'].isna()==1]
# Out:
#          Year of event Event dates                           Event name  \
# 2547794           2020  25.01.2020        North Carolina Fat Ass 50 Km
# 2551331           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551336           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551344           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551348           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# ...                ...         ...                                  ...
# 2746543           2020  17.10.2020     Black River Trail Classic 50 Km
# 2749869           2020  17.10.2020  MuleSkinner Endurance 50 Mile Race
# 2755985           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755994           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755997           2020  10.10.2020      Man Against Horse 50 Mile Race
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
df2 = df2.dropna()
df2.head()
# Out:
#          Year of event Event dates                           Event name  \
# 2538588           2020  07.02.2020   Taipei 48hr Ultra Marathon - 50mi
# 2538628           2020  07.02.2020   Taipei 48hr Ultra Marathon - 50km
# 2538860           2020  07.02.2020  Dead Sea Marathon Ein Bokek - 50km
# 2538883           2020  07.02.2020  Dead Sea Marathon Ein Bokek - 50km
# 2539317           2020  02.02.2020              Gumi Dorissa Trail Run
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2538588                  50mi                         38           10:32:38
# 2538628                  50km                         38            6:09:08
# 2538860                  50km                        179            5:12:29
# 2538883                  50km                        179            5:33:17
# 2539317                  50km                         14            7:19:11
#
#         Athlete gender Athlete average speed  Athlete ID  Athelete_Age
# ...

# %%
df2.shape
# Out:
# (26103, 10)

# %%
#check for duplicates

# %%
df.duplicated().sum()
# Out:
# 50

# %%
df2[df2.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, Athelete_Age]
# Index: []

# %%
#reset Index

# %%
df2.reset_index(drop = True)
# Out:
#        Year of event Event dates                               Event name  \
# 0               2020  07.02.2020       Taipei 48hr Ultra Marathon - 50mi
# 1               2020  07.02.2020       Taipei 48hr Ultra Marathon - 50km
# 2               2020  07.02.2020      Dead Sea Marathon Ein Bokek - 50km
# 3               2020  07.02.2020      Dead Sea Marathon Ein Bokek - 50km
# 4               2020  02.02.2020                  Gumi Dorissa Trail Run
# ...              ...         ...                                      ...
# 26098           2020  03.10.2020  Yankee Springs Fall Trail Run Festival
# 26099           2020  03.10.2020  Yankee Springs Fall Trail Run Festival
# 26100           2020  03.10.2020  Yankee Springs Fall Trail Run Festival
# 26101           2020  03.10.2020  Yankee Springs Fall Trail Run Festival
# 26102           2020  03.10.2020  Yankee Springs Fall Trail Run Festival
#
#       Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#fix Types

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# Athelete_Age                 float64
# dtype: object

# %%
df2['Athelete_Age'] = df2['Athelete_Age'].astype(int)

# %%
df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# Athelete_Age                   int32
# dtype: object

# %%
df2.head()
# Out:
#          Year of event Event dates                           Event name  \
# 2538588           2020  07.02.2020   Taipei 48hr Ultra Marathon - 50mi
# 2538628           2020  07.02.2020   Taipei 48hr Ultra Marathon - 50km
# 2538860           2020  07.02.2020  Dead Sea Marathon Ein Bokek - 50km
# 2538883           2020  07.02.2020  Dead Sea Marathon Ein Bokek - 50km
# 2539317           2020  02.02.2020              Gumi Dorissa Trail Run
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2538588                  50mi                         38           10:32:38
# 2538628                  50km                         38            6:09:08
# 2538860                  50km                        179            5:12:29
# 2538883                  50km                        179            5:33:17
# 2539317                  50km                         14            7:19:11
#
#         Athlete gender  Athlete average speed  Athlete ID  Athelete_Age
# ...

# %%
#rename columns

# %%
df2 = df2.rename(columns = {
    'Year of event' : 'Year',
    'Event dates' : 'Race_Day',
    'Event name' : 'Race_Name',
    'Event number of finishers' : 'No_of_Finishers',
    'Athlete performance' : 'Athlete_Performance',
    'Athlete gender' : 'Athlete_Gender',
    'Athlete average speed' : 'Athlete_Avg_Speed',
    'Athlete ID' : 'Athlete_Id',
    'Athelete_Age' : 'Athlete_Age'
    'Event distance/length' : 'Event_Distance'
})

# %%
df2.head()
# Out:
#          Year    Race_Day                            Race_Name Event_Distance  \
# 2538588  2020  07.02.2020   Taipei 48hr Ultra Marathon - 50mi            50mi
# 2538628  2020  07.02.2020   Taipei 48hr Ultra Marathon - 50km            50km
# 2538860  2020  07.02.2020  Dead Sea Marathon Ein Bokek - 50km            50km
# 2538883  2020  07.02.2020  Dead Sea Marathon Ein Bokek - 50km            50km
# 2539317  2020  02.02.2020              Gumi Dorissa Trail Run            50km
#
#          No_of_Finishers Athlete_Performance Athlete_Gender  \
# 2538588               38           10:32:38               M
# 2538628               38            6:09:08               M
# 2538860              179            5:12:29               M
# 2538883              179            5:33:17               M
# 2539317               14            7:19:11               M
#
#          Athlete_Avg_Speed  Athlete_Id  Athlete_Age
# 2538588              7.632        4543           45
# ...

# %%
#reorder columns

# %%
df3 = df2[['Race_Day' , 'Race_Name' , 'Event_Distance' , 'No_of_Finishers' , 'Athlete_Id' , 'Athlete_Gender' , 'Athlete_Age' ,'Athlete_Performance' , 'Athlete_Avg_Speed']]

# %%
df3
# Out:
#            Race_Day                                Race_Name Event_Distance  \
# 2538588  07.02.2020       Taipei 48hr Ultra Marathon - 50mi            50mi
# 2538628  07.02.2020       Taipei 48hr Ultra Marathon - 50km            50km
# 2538860  07.02.2020      Dead Sea Marathon Ein Bokek - 50km            50km
# 2538883  07.02.2020      Dead Sea Marathon Ein Bokek - 50km            50km
# 2539317  02.02.2020                  Gumi Dorissa Trail Run            50km
# ...             ...                                      ...            ...
# 2760957  03.10.2020  Yankee Springs Fall Trail Run Festival            50km
# 2760958  03.10.2020  Yankee Springs Fall Trail Run Festival            50km
# 2760959  03.10.2020  Yankee Springs Fall Trail Run Festival            50km
# 2760960  03.10.2020  Yankee Springs Fall Trail Run Festival            50km
# 2760961  03.10.2020  Yankee Springs Fall Trail Run Festival            50km
#
# ...

# %%
df3[df3['Race_Name'] == 'Everglades 50 Mile Ultra Run ']
# Out:
#            Race_Day                      Race_Name Event_Distance  \
# 2591476  14.03.2020  Everglades 50 Mile Ultra Run            50mi
# 2591477  14.03.2020  Everglades 50 Mile Ultra Run            50mi
# 2591478  14.03.2020  Everglades 50 Mile Ultra Run            50mi
# 2591479  14.03.2020  Everglades 50 Mile Ultra Run            50mi
# 2591480  14.03.2020  Everglades 50 Mile Ultra Run            50mi
# 2591481  14.03.2020  Everglades 50 Mile Ultra Run            50mi
# 2591482  14.03.2020  Everglades 50 Mile Ultra Run            50mi
# 2591483  14.03.2020  Everglades 50 Mile Ultra Run            50mi
# 2591484  14.03.2020  Everglades 50 Mile Ultra Run            50mi
# 2591485  14.03.2020  Everglades 50 Mile Ultra Run            50mi
# 2591486  14.03.2020  Everglades 50 Mile Ultra Run            50mi
# 2591487  14.03.2020  Everglades 50 Mile Ultra Run            50mi
# 2591488  14.03.2020  Everglades 50 Mile Ultra Run            50mi
# ...

# %%
#Charts and Graphs

# %%
sns.histplot(df3['Event_Distance'])
# Out:
# <Axes: xlabel='Event_Distance', ylabel='Count'>

# %%
sns.histplot(df3['Athlete_Gender'])
# Out:
# <Axes: xlabel='Athlete_Gender', ylabel='Count'>

# %%
sns.histplot(df3 , x = df3['Event_Distance'] ,hue = df3["Athlete_Gender"])
# Out:
# <Axes: xlabel='Event_Distance', ylabel='Count'>

# %%
sns.displot(df3[df3['Event_Distance'] == '50mi']['Athlete_Avg_Speed'])

# %%
sns.displot(df3[df3['Event_Distance'] == '50km']['Athlete_Avg_Speed'])

# %%
sns.violinplot(data = df3, x = 'Event_Distance', y = 'Athlete_Avg_Speed', hue = 'Athlete_Gender', split = True, inner = 'quart', linewidth=1)
# Out:
# <Axes: xlabel='Event_Distance', ylabel='Athlete_Avg_Speed'>

# %%
#Questions I need to Find out from the data

# %%
df3.dtypes
# Out:
# Race_Day                object
# Race_Name               object
# Event_Distance          object
# No_of_Finishers          int64
# Athlete_Id               int64
# Athlete_Gender          object
# Athlete_Age              int32
# Athlete_Performance     object
# Athlete_Avg_Speed      float64
# dtype: object

# %%
#difference in speed for the 50k, 50mi male to female

# %%
df3.groupby(['Event_Distance','Athlete_Gender'])['Athlete_Avg_Speed'].mean()
# Out:
# Event_Distance  Athlete_Gender
# 50km            F                 7.086604
#                 M                 7.732760
# 50mi            F                 6.827333
#                 M                 7.236600
# Name: Athlete_Avg_Speed, dtype: float64

# %%
#What age Groups are the best in the 50mi Race(20+Race min)(Show 15)

# %%
df3.query('Event_Distance == "50mi"').groupby('Athlete_Age')['Athlete_Avg_Speed'].agg(['mean','count']).sort_values('mean',ascending = False).query('count>19').head(15)
# Out:
#                  mean  count
# Athlete_Age
# 29           7.894074    136
# 23           7.779800     55
# 28           7.575252    107
# 30           7.572708    154
# 25           7.471053     95
# 35           7.422943    194
# 38           7.417961    232
# 31           7.371059    136
# 22           7.367902     41
# 36           7.367011    182
# 33           7.355408    147
# 26           7.328584     77
# 24           7.327203     74
# 42           7.322952    208
# 34           7.312779    181

# %%
#What age Groups are the worst in the 50mi Race(20+Race min)(Show 15)

# %%
df3.query('Event_Distance == "50mi"').groupby('Athlete_Age')['Athlete_Avg_Speed'].agg(['mean','count']).sort_values('mean',ascending = True).query('count>19').head(15)
# Out:
#                  mean  count
# Athlete_Age
# 60           6.202250     32
# 62           6.267564     39
# 61           6.358355     31
# 63           6.535759     29
# 58           6.579862     65
# 64           6.620727     22
# 48           6.644000    130
# 50           6.648130    169
# 56           6.653379     66
# 59           6.665573     82
# 53           6.724598     97
# 57           6.792104     77
# 54           6.792429     84
# 49           6.796887    159
# 55           6.798870     69

# %%
#Seasons For the data -> Slower in Summer than Winter?

#Spring 3-5
#Summer 6-8
#Fall 9-11
#Winter 12-2

#Split Between two Decimals

# %%
df3['Race_Month'] = df3['Race_Day'].str.split('.').str.get(1).astype(int)
df3['Race_Month']
# Out:
# 2538588     2
# 2538628     2
# 2538860     2
# 2538883     2
# 2539317     2
#            ..
# 2760957    10
# 2760958    10
# 2760959    10
# 2760960    10
# 2760961    10
# Name: Race_Month, Length: 26103, dtype: int32

# %%
df3['Race_Season'] = df3['Race_Month'].apply(lambda x: 'Winter' if x>11 else 'Fall' if x>8 else 'Summer' if x>5 else 'Spring' if x>2 else 'Winter')

# %%
df3.tail(5)
# Out:
#            Race_Day                                Race_Name Event_Distance  \
# 2760957  03.10.2020  Yankee Springs Fall Trail Run Festival            50km
# 2760958  03.10.2020  Yankee Springs Fall Trail Run Festival            50km
# 2760959  03.10.2020  Yankee Springs Fall Trail Run Festival            50km
# 2760960  03.10.2020  Yankee Springs Fall Trail Run Festival            50km
# 2760961  03.10.2020  Yankee Springs Fall Trail Run Festival            50km
#
#          No_of_Finishers  Athlete_Id Athlete_Gender  Athlete_Age  \
# 2760957               30      816361              F           62
# 2760958               30      326469              F           43
# 2760959               30      372174              F           58
# 2760960               30      860349              F           39
# 2760961               30      770097              M           40
#
#         Athlete_Performance  Athlete_Avg_Speed  Race_Month Race_Season
# ...

# %%
df3.groupby('Race_Season')['Athlete_Avg_Speed'].agg(['mean','count']).sort_values("mean",ascending = False)
# Out:
#                  mean  count
# Race_Season
# Spring       7.686644   3344
# Winter       7.515420  11683
# Fall         7.403381   8300
# Summer       6.856466   2776

# %%
df3.query('Event_Distance == "50mi"').groupby('Race_Season')['Athlete_Avg_Speed'].agg(['mean','count']).sort_values("mean",ascending = False)
# Out:
#                  mean  count
# Race_Season
# Fall         7.506842   1988
# Spring       7.068189    795
# Winter       7.026111   1923
# Summer       6.495946    859
